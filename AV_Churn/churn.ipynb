# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train.csv')
# Out:
# /home/greed/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (294,299,300,302,307,313,315,365,367,369) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
obj_df = df_train.select_dtypes(include=['object']).copy()

# %%
obj_df.shape
# Out:
# (300000, 38)

# %%
obj_df.dropna(axis=1, how='any', inplace=True)

# %%
obj_df.shape
# Out:
# (300000, 8)

# %%
obj_df.columns
# Out:
# Index(['HNW_CATEGORY', 'EFT_SELF_TRANSFER_PrevQ1', 'Billpay_Active_PrevQ1_N',
#        'Billpay_Reg_ason_Prev1_N', 'Charges_cnt_PrevQ1_N', 'FRX_PrevQ1_N',
#        'RBI_Class_Audit', 'gender_bin'],
#       dtype='object')

# %%
cleanup_nums = {'HNW_CATEGORY':     {"1_Imperia": 1, "2_Preferred": 2, "3_Classic":3},
                'EFT_SELF_TRANSFER_PrevQ1': {'Y':1, 'N':0},
                'Billpay_Active_PrevQ1_N': {'A_MISSING':0,'B_1':1},
                'Billpay_Reg_ason_Prev1_N':{'A_MISSING':0,'B_1':1},
                'Charges_cnt_PrevQ1_N' : {'A_MISSING':0,'B_1':1,'C_2':2,'D_3':3},
                'FRX_PrevQ1_N': {'A_MISSING':0,'B_1':1},
                'RBI_Class_Audit': {'METROPOLITAN':0, 'URBAN':1,'SEMI-URBAN':2,'RURAL':3},
                'gender_bin' : {'Male':0, 'Female':1,'Missin':2}
               }

# %%
obj_df['gender_bin'].value_counts()
# Out:
# Male      174827
# Female    119212
# Missin      5961
# Name: gender_bin, dtype: int64

# %%
obj_df.replace(cleanup_nums, inplace=True)
obj_df.head()
# Out:
#    HNW_CATEGORY  EFT_SELF_TRANSFER_PrevQ1  Billpay_Active_PrevQ1_N  \
# 0             2                         0                        0
# 1             1                         0                        0
# 2             2                         0                        0
# 3             3                         0                        0
# 4             2                         0                        0
#
#    Billpay_Reg_ason_Prev1_N  Charges_cnt_PrevQ1_N  FRX_PrevQ1_N  \
# 0                         0                     0             0
# 1                         1                     0             0
# 2                         0                     0             0
# 3                         0                     3             0
# 4                         0                     0             0
#
#    RBI_Class_Audit  gender_bin
# 0                2           1
# 1                0           0
# 2                1           0
# 3                3           0
# ...

# %%
df_train.dropna(axis=1, how='any', inplace=True)
df_train.shape
# Out:
# (300000, 206)

# %%
df_train.columns
# Out:
# Index(['UCIC_ID', 'NO_OF_Accs', 'HNW_CATEGORY', 'vintage', 'C_prev1',
#        'D_prev1', 'ATM_C_prev1', 'ATM_D_prev1', 'BRANCH_C_prev1',
#        'BRANCH_D_prev1',
#        ...
#        'I_CNR_PrevQ1', 'I_CNR_PrevQ2', 'I_NRV_PrevQ1', 'I_NRV_PrevQ2',
#        'CR_AMB_Drop_Build_1', 'CR_AMB_Drop_Build_2', 'CR_AMB_Drop_Build_3',
#        'CR_AMB_Drop_Build_4', 'CR_AMB_Drop_Build_5', 'Responders'],
#       dtype='object', length=206)

# %%
df_train.replace(cleanup_nums, inplace=True)

df_train.head()
# Out:
#    UCIC_ID  NO_OF_Accs  HNW_CATEGORY  vintage     C_prev1    D_prev1  \
# 0   170114           1             2     1947        0.00   200000.0
# 1   488013           1             1     3082     3198.40    32000.0
# 2   435239           1             2      572    15000.00  1650000.0
# 3   331646           1             3      773        0.00        0.0
# 4   226900           1             2     1627  1057252.95   835000.0
#
#    ATM_C_prev1  ATM_D_prev1  BRANCH_C_prev1  BRANCH_D_prev1     ...      \
# 0            0          0.0            0.00        200000.0     ...
# 1            0      18000.0         3198.40         14000.0     ...
# 2            0          0.0        15000.00       1650000.0     ...
# 3            0          0.0            0.00             0.0     ...
# 4            0          0.0      1057252.95        835000.0     ...
#
#    I_CNR_PrevQ1  I_CNR_PrevQ2  I_NRV_PrevQ1  I_NRV_PrevQ2  \
# 0   1826.046667   2154.266667  9.007502e+05  1.034232e+06
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Columns: 206 entries, UCIC_ID to Responders
# dtypes: float64(93), int64(113)
# memory usage: 471.5 MB

# %%
df_train.info() #earlier before converting strings to int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Columns: 206 entries, UCIC_ID to Responders
# dtypes: float64(93), int64(113)
# memory usage: 471.5 MB

# %%
df_train.loc[:, df_train.dtypes == object].columns
# Out:
# Index([], dtype='object')

# %%
df_train.drop(['UCIC_ID'], axis = 1, inplace = True)

# %%
df_train.head()
# Out:
#    NO_OF_Accs  HNW_CATEGORY  vintage     C_prev1    D_prev1  ATM_C_prev1  \
# 0           1             2     1947        0.00   200000.0            0
# 1           1             1     3082     3198.40    32000.0            0
# 2           1             2      572    15000.00  1650000.0            0
# 3           1             3      773        0.00        0.0            0
# 4           1             2     1627  1057252.95   835000.0            0
#
#    ATM_D_prev1  BRANCH_C_prev1  BRANCH_D_prev1  IB_C_prev1     ...      \
# 0          0.0            0.00        200000.0         0.0     ...
# 1      18000.0         3198.40         14000.0         0.0     ...
# 2          0.0        15000.00       1650000.0         0.0     ...
# 3          0.0            0.00             0.0         0.0     ...
# 4          0.0      1057252.95        835000.0         0.0     ...
#
#    I_CNR_PrevQ1  I_CNR_PrevQ2  I_NRV_PrevQ1  I_NRV_PrevQ2  \
# ...

# %%
y = df_train.Responders.values
y.reshape(300000,1)
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
X = df_train.drop(['Responders'], axis = 1)
X.shape
# Out:
# (300000, 204)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (225000, 204)
# (75000, 204)
# (225000,)
# (75000,)

# %%
logreg = LogisticRegression()
# logreg.fit(X_train, y_train)

# %%
# y_pred = logreg.predict(X_test)
# print (metrics.accuracy_score(y_test, y_pred))

# %%
df_test = pd.read_csv('test.csv')
# Out:
# /home/greed/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (294,299,300,302,313,315,365,367,369) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
uid = df_test['UCIC_ID']

# %%
df_test.shape
# Out:
# (200000, 376)

# %%
df_test.dropna(axis=1, how='any', inplace=True)
df_test.shape
# Out:
# (200000, 205)

# %%
df_test.drop(['UCIC_ID'], axis = 1, inplace = True)

# %%
df_test.replace(cleanup_nums, inplace=True)
df_test.head()
# Out:
#    NO_OF_Accs  HNW_CATEGORY  vintage     C_prev1     D_prev1  ATM_C_prev1  \
# 0           2             2      463   171500.00   332000.00            0
# 1           1             1     3822    15450.00        0.00            0
# 2           1             2      682        0.00        0.00            0
# 3           1             2      552  1500011.45  1026399.54            0
# 4           1             2     2018    30000.00   100317.90            0
#
#    ATM_D_prev1  BRANCH_C_prev1  BRANCH_D_prev1  IB_C_prev1  \
# 0       5000.0       171500.00        327000.0         0.0
# 1          0.0        15450.00             0.0         0.0
# 2          0.0            0.00             0.0         0.0
# 3       5000.0      1500011.45       1002000.0         0.0
# 4          0.0        30000.00         13792.0         0.0
#
#           ...           I_CR_AQB_PrevQ2  I_CNR_PrevQ1  I_CNR_PrevQ2  \
# 0         ...              3.760351e+05    885.370000    495.876667
# ...

# %%
# logreg.fit(X, y)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(X, y)
y_pred = tree.predict(df_test)

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()
forest.fit(X, y)
y_pred = forest.predict(df_test)

# %%
# y_pred = tree.predict(df_test)

# %%
sub = pd.DataFrame({'UCIC_ID':uid.values, 'Responders':y_pred})

# %%
sub.set_index('UCIC_ID', inplace = True)

# %%
sub.head()
# Out:
#          Responders
# UCIC_ID
# 337734            1
# 488166            0
# 410785            0
# 389145            0
# 221090            0

# %%
# sub.to_csv('dt-submission.csv')

# %%
y = y.reshape(300000,1)

# %%
from keras.models import Sequential
from keras.layers import Dense
print(X.shape, y.shape)
# Out:
# (300000, 204) (300000, 1)

# %%
# create model
model = Sequential()
model.add(Dense(400, input_dim=204, activation='relu'))
model.add(Dense(400, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, y, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-22eebaef1a72> in <module>()
#       1 # Fit the model
# ----> 2 model.fit(X, y, epochs=10, batch_size=10)
#
# /home/greed/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     865                               class_weight=class_weight,
#     866                               sample_weight=sample_weight,
# --> 867                               initial_epoch=initial_epoch)
#     868
#     869     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ...

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
from keras.models import model_from_yaml

from sklearn.model_selection import train_test_split
from sklearn import metrics 

import numpy
import pandas as pd

df_train = pd.read_csv('num-train.csv')
df_test = pd.read_csv('num-test.csv')

test_actual = pd.read_csv('test.csv')
uid = test_actual['UCIC_ID']

# # split into input (X) and output (y) variables
# X = df_train.drop(['Responders'], axis = 1)
# y = df_train.Responders.values

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, test_size = 0.9)

# # create model
# model = Sequential()
# model.add(Dense(400, input_dim=204, activation='relu'))
# model.add(Dense(400, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))
# # Compile model
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# # Fit the model
# model.fit(X_train.values, y_train, epochs=10, batch_size=10)
# # evaluate the model
# scores = model.evaluate(X_test.values, y_test)
# print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))



# model.fit(X.values, y, epochs=10, batch_size=10)

# try : 
#     y_pred = model.predict(df_test.values)
#     print(type(y_pred))
#     subm = pd.DataFrame({'UCIC_ID':uid.values, 'Responders':y_pred})
#     subm.set_index('UCIC_ID', inplace = True)
#     subm.to_csv('mlp-keras-submission.csv')
# except Exception as e:
#     print(e)

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

predictions = loaded_model.predict(df_test.values)
# round predictions
rounded = [round(x[0]) for x in predictions]
print(rounded)

df = pd.DataFrame({'Responders':rounded})

# # serialize model to JSON
# model_json = model.to_json()
# with open("model.json", "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# model.save_weights("model.h5")
# print("Saved model to disk")

# # serialize model to YAML
# model_yaml = model.to_yaml()
# with open("model.yaml", "w") as yaml_file:
#     yaml_file.write(model_yaml)
# Out:
# Using TensorFlow backend.
# /home/greed/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (294,299,300,302,313,315,365,367,369) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Loaded model from disk
# ...

# %%
df['Responders'].value_counts()
# Out:
# 0.0    200000
# Name: Responders, dtype: int64

# %%
uid.values
# Out:
# array([337734, 488166, 410785, ..., 203554, 332138, 103794])

# %%
df['UCIC_ID'] = uid.values

# %%
df.set_index('UCIC_ID', inplace = True)

# %%
df.to_csv('mlpzero.csv')

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")

# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

predictions = loaded_model.predict(df_test.values)
# round predictions
rounded = [round(x[0]) for x in predictions]
print(rounded)
