# %%
import pandas as pd
from matplotlib import pyplot as plt, style
# %matplotlib inline

style.use('fivethirtyeight')

table = pd.read_csv('cities_r2.csv')

# %%
table.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female    ...      child_sex_ratio  \
# 0                 8587                   7283    ...                  848
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
table.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
table.state_name.value_counts()
# Out:
# UTTAR PRADESH                63
# WEST BENGAL                  61
# MAHARASHTRA                  43
# ANDHRA PRADESH               42
# MADHYA PRADESH               32
# TAMIL NADU                   32
# RAJASTHAN                    29
# GUJARAT                      29
# BIHAR                        26
# KARNATAKA                    26
# HARYANA                      20
# PUNJAB                       16
# NCT OF DELHI                 15
# ORISSA                       10
# JHARKHAND                    10
# CHHATTISGARH                  9
# KERALA                        7
# UTTARAKHAND                   6
# ASSAM                         4
# JAMMU & KASHMIR               3
# PUDUCHERRY                    2
# MEGHALAYA                     1
# MIZORAM                       1
# HIMACHAL PRADESH              1
# NAGALAND                      1
# CHANDIGARH                    1
# TRIPURA                       1
# ANDAMAN & NICOBAR ISLANDS     1
# MANIPUR                       1
# ...

# %%
table.state_name.value_counts().hist()

# %%
table.hist(bins = 50, figsize = (20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d76318fd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d6fffcb70>]], dtype=object)

# %%
from sklearn.cross_validation import train_test_split
train_set, test_set = train_test_split(table, test_size = 0.2, random_state = 7)

# %%
for_plotting = pd.read_csv('cities_r2.csv')

# %%
latitude, longitude = [], []
for i in for_plotting['location']:
    latitude.append(float(i.split(',')[0]))
    longitude.append(float(i.split(',')[1]))

# %%
from mpl_toolkits.basemap import Basemap

fig, ax = plt.subplots(figsize=(20,20))
m = Basemap(resolution='l', # c, l, i, h, f or None
            projection='mill',
            lat_0=20.5937, lon_0=78.9629,
            llcrnrlon=64.31, llcrnrlat= 5.11, urcrnrlon=99.87, urcrnrlat=36.72)


m.fillcontinents(color='0.95')
m.drawcoastlines(color = '0.5', linewidth = 0.25)
m.drawcountries(linewidth = 0.5)
m.drawmapboundary(fill_color= '#e1f7f2')

x,y = m(longitude, latitude)
m.plot(x, y, 'bo', alpha = 0.7)
# Out:
# /home/greed/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /home/greed/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/greed/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
table.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
ea = ['population_total', 'population_male', 'population_female',
       '0-6_population_total', '0-6_population_male', '0-6_population_female',
       'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
       'child_sex_ratio', 'effective_literacy_rate_total',
       'effective_literacy_rate_male', 'effective_literacy_rate_female',
       'total_graduates', 'male_graduates', 'female_graduates'] # essential attributes for correlation

# %%
corr_matrix = table[ea].corr()

# %%
corr_matrix
# Out:
#                                 population_total  population_male  \
# population_total                        1.000000         0.999647
# population_male                         0.999647         1.000000
# population_female                       0.999547         0.998395
# 0-6_population_total                    0.991590         0.991738
# 0-6_population_male                     0.989977         0.990528
# 0-6_population_female                   0.992786         0.992482
# literates_total                         0.998777         0.998473
# literates_male                          0.998561         0.999003
# literates_female                        0.997831         0.996611
# sex_ratio                              -0.127811        -0.139004
# child_sex_ratio                        -0.027147        -0.034290
# effective_literacy_rate_total           0.079707         0.077046
# effective_literacy_rate_male            0.039787         0.037451
# ...

# %%
female_attributes = ['population_female', '0-6_population_female', 
                     'literates_total', 'literates_female', 'sex_ratio', 'child_sex_ratio', 'female_graduates', 
                     'effective_literacy_rate_total']

# %%
female_correlation = table[female_attributes].corr()
female_correlation
# Out:
#                                population_female  0-6_population_female  \
# population_female                       1.000000               0.992283
# 0-6_population_female                   0.992283               1.000000
# literates_total                         0.998270               0.987920
# literates_female                        0.998361               0.985984
# sex_ratio                              -0.115034              -0.150968
# child_sex_ratio                        -0.019040              -0.043724
# female_graduates                        0.978455               0.967855
# effective_literacy_rate_total           0.082651               0.051988
#
#                                literates_total  literates_female  sex_ratio  \
# population_female                     0.998270          0.998361  -0.115034
# 0-6_population_female                 0.987920          0.985984  -0.150968
# literates_total                       1.000000          0.999331  -0.117465
# ...

# %%
import seaborn as sns

# %%
corr_matrix['effective_literacy_rate_total'].sort_values(ascending = False)
# Out:
# effective_literacy_rate_total     1.000000
# effective_literacy_rate_female    0.972706
# effective_literacy_rate_male      0.954109
# state_code                        0.387393
# sex_ratio                         0.255789
# child_sex_ratio                   0.139637
# female_graduates                  0.113892
# literates_female                  0.113412
# total_graduates                   0.108405
# literates_total                   0.105607
# male_graduates                    0.103764
# literates_male                    0.099151
# population_female                 0.082651
# longitude                         0.080488
# population_total                  0.079707
# population_male                   0.077046
# 0-6_population_female             0.051988
# 0-6_population_total              0.050218
# 0-6_population_male               0.048611
# dist_code                         0.005983
# latitude                         -0.342765
# Name: effective_literacy_rate_total, dtype: float64

# %%
import seaborn as sns
data = table[attributes]
sns.pairplot(data)

# %%
import seaborn as sns
attributes = ['population_total', 'effective_literacy_rate_total', 'sex_ratio', 'literates_total', 'state_name']
data = table[attributes]
sns.pairplot(data, hue = 'state_name', size = 4)
